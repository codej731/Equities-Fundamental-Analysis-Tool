# %%
import pandas as pd
import yfinance as yf
import numpy as np
from finvizfinance.screener.overview import Overview
from scipy.stats import linregress
import time

# %%
# ==========================================
# 1.(Finviz Screening)
# ==========================================
def get_filtered_picks(limit_per_country=5000): # Raised limit to capture more
    print("--- STEP 1: Fetching Universe from Finviz ---")
    
    try:
        foverview = Overview()
        
        # Criteria: USA, Strong Buy, High Liquidity, Not Penny Stocks
        filters_dict = {
            'Analyst Recom.': 'Strong Buy (1)',
            'Country': 'USA',
            'Average Volume': 'Over 2M', 
            'Market Cap.': '+Small (over $300mln)'
        }
        foverview.set_filter(filters_dict=filters_dict)
        df_results = foverview.screener_view()
        
        if df_results.empty:
            return pd.DataFrame()
            
        print(f"   Success! Found {len(df_results)} initial candidates.")
        
        # Clean up Column Names immediately
        if 'Analyst Recom' in df_results.columns:
            df_results.rename(columns={'Analyst Recom': 'Recom'}, inplace=True)
            
        # Ensure numeric Price for later
        df_results['Price'] = pd.to_numeric(df_results['Price'], errors='coerce')
        
        return df_results

    except Exception as e:
        print(f"   Error in Finviz Step: {e}")
        return pd.DataFrame()

# %%
# ==========================================
# 2. THE CREDIT MODEL (Z-Score & Margins)
# ==========================================
def calculate_z_score(info, financials, balance_sheet):
    """Calculates Altman Z-Score (Bankruptcy Risk)"""
    try:
        # Extract Key Metrics
        total_assets = balance_sheet.loc['Total Assets'].iloc[0]
        total_liab = balance_sheet.loc['Total Liabilities Net Minority Interest'].iloc[0]
        current_assets = balance_sheet.loc['Current Assets'].iloc[0]
        current_liab = balance_sheet.loc['Current Liabilities'].iloc[0]
        
        # Z-Score Components
        working_capital = current_assets - current_liab
        retained_earnings = balance_sheet.loc['Retained Earnings'].iloc[0] if 'Retained Earnings' in balance_sheet.index else 0
        
        # Handle EBIT naming differences
        if 'Ebit' in financials.index:
            ebit = financials.loc['Ebit'].iloc[0]
        elif 'Operating Income' in financials.index:
            ebit = financials.loc['Operating Income'].iloc[0]
        else:
            return np.nan
            
        market_cap = info.get('marketCap', 0)
        sales = financials.loc['Total Revenue'].iloc[0]

        # Ratios
        A = working_capital / total_assets
        B = retained_earnings / total_assets
        C = ebit / total_assets
        D = market_cap / total_liab
        E = sales / total_assets

        # Formula: 1.2A + 1.4B + 3.3C + 0.6D + 1.0E Altman Z-Score coefficients
        z_score = (1.2 * A) + (1.4 * B) + (3.3 * C) + (0.6 * D) + (1.0 * E)
        return round(z_score, 2)
    except:
        return np.nan

def get_margin_trend(financials):
    """Calculates 3-Year Gross Margin Slope"""
    try:
        years = financials.columns[:3]
        margins = []
        for date in years:
            rev = financials.loc['Total Revenue'][date]
            profit = financials.loc['Gross Profit'][date]
            if rev == 0 or np.isnan(rev): margins.append(0)
            else: margins.append(profit/rev)
            
        # Slope Calculation
        margins = margins[::-1] # Chronological order
        slope, _, _, _, _ = linregress(range(len(margins)), margins)
        
        if slope > 0.005: return "Improving"
        elif slope < -0.005: return "Deteriorating"
        else: return "Stable"
    except:
        return "N/A"

# %%
# ==========================================
# 3. EXECUTION ENGINE (SPLIT BY TIER)
# ==========================================
import time

def run_screener_split():
    # A. Get the List from Step 1
    candidates = get_filtered_picks()
    
    if candidates.empty:
        print("No stocks found to analyze.")
        return None, None, None, None, None

    print(f"\n--- STEP 2: Running Credit Risk Model on {len(candidates)} Stocks ---")
    print("Separating stocks into distinct tiers...")
    
    # Initialize separate lists for each tier
    fortress_data = []
    moonshot_data = []
    distress_data = []
    financial_data = [] # Banks/Insurance (skipped by Z-score)
    middle_data = []    # Everything else
    
    # Loop through ALL candidates
    for index, row in candidates.iterrows():
        ticker = row['Ticker']
        
        try:
            stock = yf.Ticker(ticker)
            info = stock.info
            
            # 1. SEPARATE FINANCIALS
            # Z-Score doesn't work for banks, so we stash them here to analyze later
            sector = info.get('sector', 'Unknown')
            if 'Financial' in sector:
                financial_data.append({
                    'Ticker': ticker,
                    'Sector': sector,
                    'Price': row['Price'],
                    'Recom': row.get('Recom', 'N/A')
                })
                continue
            
            # 2. FETCH DATA
            fin = stock.financials
            bs = stock.balance_sheet
            
            if fin.empty or bs.empty:
                continue
            
            # 3. RUN METRICS (Using your helper functions)
            z_score = calculate_z_score(info, fin, bs)
            trend = get_margin_trend(fin)
            
            # Data packet to save
            stock_data = {
                'Ticker': ticker,
                'Company': row.get('Company', 'N/A'),
                'Z-Score': z_score,
                'Margin_Trend': trend,
                'Price': row['Price'],
                'Recom': row.get('Recom', 'N/A'),
                'Sector': sector
            }
            
            # 4. SORT INTO LISTS (The Logic)
            if (z_score > 2.99) and (trend in ["Improving", "Stable"]):
                fortress_data.append(stock_data)
                
            elif (z_score < 1.8) and (trend == "Deteriorating"):
                distress_data.append(stock_data)
                
            elif (z_score < 1.8) and (trend == "Improving"):
                moonshot_data.append(stock_data)
            
            else:
                middle_data.append(stock_data)
            
            # Progress indicator
            if index % 10 == 0:
                print(f"   Processed {index} / {len(candidates)}...", end='\r')

        except Exception:
            continue

    # B. Convert Lists to DataFrames
    fortress_df = pd.DataFrame(fortress_data)
    moonshot_df = pd.DataFrame(moonshot_data)
    distress_df = pd.DataFrame(distress_data)
    financial_df = pd.DataFrame(financial_data)
    middle_df = pd.DataFrame(middle_data)
    
    print(f"\n\n--- ANALYSIS COMPLETE ---")
    print(f"Fortress (Safe):     {len(fortress_df)} stocks")
    print(f"Moonshot (Risky):    {len(moonshot_df)} stocks")
    print(f"Distress (Avoid):    {len(distress_df)} stocks")
    print(f"Financials (Skip):   {len(financial_df)} stocks")
    print(f"Middle of Road:      {len(middle_df)} stocks")
    
    return fortress_df, moonshot_df, distress_df, financial_df, middle_df

# --- RUN IT & UNPACK VARIABLES ---
# This saves the results into 5 separate dataframes immediately
fortress_df, moonshot_df, distress_df, fins_df, mid_df = run_screener_split()
#fins_df are banking and other financial sector stocks cannot use Z score due to customer deposits being liabilities
# Out:
# --- STEP 1: Fetching Universe from Finviz ---
#    Success! Found 397 initial candidates.########--] 19/20
#
# --- STEP 2: Running Credit Risk Model on 397 Stocks ---
# Separating stocks into distinct tiers...
#    Processed 380 / 397...
# c:\ProgramData\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:10730: RuntimeWarning: invalid value encountered in scalar divide
#   slope = ssxym / ssxm
# c:\ProgramData\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:10744: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# c:\ProgramData\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:10750: RuntimeWarning: invalid value encountered in scalar divide
#   slope_stderr = np.sqrt((1 - r**2) * ssym / ssxm / df)
#    Processed 390 / 397...
#
# --- ANALYSIS COMPLETE ---
# Fortress (Safe):     104 stocks
# Moonshot (Risky):    49 stocks
# Distress (Avoid):    33 stocks
# Financials (Skip):   36 stocks
# Middle of Road:      171 stocks

# %%
if fortress_df is not None and not fortress_df.empty:
    print("--- FORTRESS STOCKS (High Quality) ---")
    # Sort by Z-Score to find the healthiest balance sheets aka safe picks
    display(fortress_df.sort_values(by='Z-Score', ascending=False))
# Out:
# --- FORTRESS STOCKS (High Quality) ---
#     Ticker                             Company  Z-Score Margin_Trend   Price  \
# 67    PPTA             Perpetua Resources Corp   223.80       Stable   27.60
# 73     QXO                             QXO Inc   195.61       Stable   21.80
# 96    UMAC                Unusual Machines Inc   165.18    Improving    9.85
# 74    RCAT                Red Cat Holdings Inc   113.14    Improving    8.05
# 62    NVDA                         NVIDIA Corp    87.02    Improving  180.99
# ..     ...                                 ...      ...          ...     ...
# 9      APG               APi Group Corporation     3.07    Improving   38.88
# 103    XPO                             XPO Inc     3.07    Improving  138.52
# 81     SLB                             SLB Ltd     3.06    Improving   38.08
# 91    TTWO  Take-Two Interactive Software, Inc     3.06    Improving  247.40
# 38     HAS                         Hasbro, Inc     3.03    Improving   81.98
#
#     Recom                  Sector
# 67    N/A         Basic Materials
# 73    N/A             Industrials
# 96    N/A              Technology
# 74    N/A             Industrials
# 62    N/A              Technology
# ..    ...                     ...
# 9     N/A             Industrials
# 103   N/A             Industrials
# 81    N/A                  Energy
# 91    N/A  Communication Services
# 38    N/A       Consumer Cyclical
#
# [104 rows x 7 columns]

# %%
#high risk picks
if moonshot_df is not None and not moonshot_df.empty:
    print("--- MOONSHOT STOCKS (Speculative) ---")
    # Sort by Price (Cheapest first?) or Recom
    display(moonshot_df.sort_values(by='Price', ascending=True))
# Out:
# --- MOONSHOT STOCKS (Speculative) ---
#    Ticker                              Company  Z-Score Margin_Trend   Price  \
# 25   LCTX        Lineage Cell Therapeutics Inc     1.27    Improving    1.68
# 1    ALIT                           Alight Inc     0.36    Improving    1.94
# 10   CERS                           Cerus Corp    -4.56    Improving    2.09
# 23   GUTS                   Fractyl Health Inc    -5.39    Improving    2.20
# 11   CLNE              Clean Energy Fuels Corp    -0.07    Improving    2.23
# 30   MVST               Microvast Holdings Inc    -0.14    Improving    2.94
# 18   EVGO                             EVgo Inc     1.04    Improving    3.05
# 9    CDZI                            Cadiz Inc    -4.75    Improving    5.35
# 0    AIOT                       PowerFleet Inc     0.94    Improving    5.36
# 46    VIR                Vir Biotechnology Inc     0.71    Improving    5.76
# 3    AQST           Aquestive Therapeutics Inc    -2.00    Improving    5.80
# 29   MNKD                        Mannkind Corp    -7.24    Improving    5.84
# 42     TE                        T1 Energy Inc    -0.04    Improving    6.43
# 16   EOLS                           Evolus Inc    -1.24    Improving    7.07
# 48   XERS         Xeris Biopharma Holdings Inc    -0.31    Improving    7.34
# 41   TDUP                          ThredUp Inc     1.05    Improving    7.48
# 22   GBTG     Global Business Travel Group Inc     1.31    Improving    7.84
# 15   ENVX                   Enovix Corporation     0.85    Improving    7.86
# 14   ECVT                          Ecovyst Inc     1.17    Improving    9.59
# 2    AMRX           Amneal Pharmaceuticals Inc     1.70    Improving   12.57
# 20   FOLD              Amicus Therapeutics Inc     0.92    Improving   14.18
# 38    SEM  Select Medical Holdings Corporation     1.59    Improving   15.01
# 36   REAL                      Therealreal Inc    -1.91    Improving   15.52
# 12   CORZ                  Core Scientific Inc    -1.20    Improving   15.60
# 39   SGRY                 Surgery Partners Inc     0.82    Improving   15.70
# 35   PRMB                    Primo Brands Corp     0.91    Improving   16.10
# 21   FWRG     First Watch Restaurant Group Inc     1.29    Improving   16.21
# 17     ET                   Energy Transfer LP     1.34    Improving   16.39
# 28   MGNI                          Magnite Inc     0.73    Improving   16.40
# 31    NIQ          NIQ Global Intelligence plc     0.74    Improving   16.60
# 19   EXTR                 Extreme Networks Inc     1.08    Improving   16.85
# 34   PHAT          Phathom Pharmaceuticals Inc    -4.89    Improving   17.53
# 37   SDGR                      Schrodinger Inc     1.11    Improving   17.66
# 27    MDU              MDU Resources Group Inc     1.12    Improving   19.17
# 7    BKSY              BlackSky Technology Inc    -0.81    Improving   19.25
# 32   NTSK                         Netskope Inc    -0.15    Improving   19.26
# 5    ATEC                Alphatec Holdings Inc     0.62    Improving   20.01
# 40   SNDX           Syndax Pharmaceuticals Inc    -0.57    Improving   20.77
# 45   URGN                    UroGen Pharma Ltd    -1.61    Improving   22.80
# 33    PGY              Pagaya Technologies Ltd     1.30    Improving   22.85
# 4    AROC                         Archrock Inc     0.81    Improving   25.34
# 26    LTH         Life Time Group Holdings Inc     1.16    Improving   26.44
# 24     KD                 Kyndryl Holdings Inc     1.78    Improving   27.08
# 8     CAI              Caris Life Sciences Inc    -9.50    Improving   27.94
# 44    UGI                             UGI Corp     1.45    Improving   38.10
# 13    DAL                 Delta Air Lines, Inc     1.44    Improving   71.06
# 6    BBIO                 BridgeBio Pharma Inc    -2.10    Improving   76.30
# 43    UAL         United Airlines Holdings Inc     1.42    Improving  113.99
# 47   WYNN                     Wynn Resorts Ltd     1.41    Improving  127.94
#
#    Recom                  Sector
# 25   N/A              Healthcare
# 1    N/A              Technology
# 10   N/A              Healthcare
# 23   N/A              Healthcare
# 11   N/A                  Energy
# 30   N/A       Consumer Cyclical
# 18   N/A       Consumer Cyclical
# 9    N/A               Utilities
# 0    N/A              Technology
# 46   N/A              Healthcare
# 3    N/A              Healthcare
# 29   N/A              Healthcare
# 42   N/A             Industrials
# 16   N/A              Healthcare
# 48   N/A              Healthcare
# 41   N/A       Consumer Cyclical
# 22   N/A       Consumer Cyclical
# 15   N/A             Industrials
# 14   N/A         Basic Materials
# 2    N/A              Healthcare
# 20   N/A              Healthcare
# 38   N/A              Healthcare
# 36   N/A       Consumer Cyclical
# 12   N/A              Technology
# 39   N/A              Healthcare
# 35   N/A      Consumer Defensive
# 21   N/A       Consumer Cyclical
# 17   N/A                  Energy
# 28   N/A  Communication Services
# 31   N/A                 Unknown
# 19   N/A              Technology
# 34   N/A              Healthcare
# 37   N/A              Healthcare
# 27   N/A               Utilities
# 7    N/A             Industrials
# 32   N/A              Technology
# 5    N/A              Healthcare
# 40   N/A              Healthcare
# 45   N/A              Healthcare
# 33   N/A              Technology
# 4    N/A                  Energy
# 26   N/A       Consumer Cyclical
# 24   N/A              Technology
# 8    N/A              Healthcare
# 44   N/A               Utilities
# 13   N/A             Industrials
# 6    N/A              Healthcare
# 43   N/A             Industrials
# 47   N/A       Consumer Cyclical

# %%
#very high risk / avoid picks
if distress_df is not None and not distress_df.empty:
    print("--- DISTRESS (Avoid / Short Candidates) ---")
    display(distress_df.sort_values(by='Z-Score', ascending=True))
# Out:
# --- DISTRESS (Avoid / Short Candidates) ---
#    Ticker                               Company  Z-Score   Margin_Trend  \
# 3    AKBA               Akebia Therapeutics Inc    -9.52  Deteriorating
# 32   ZVRA                Zevra Therapeutics Inc    -3.07  Deteriorating
# 29   VERI                          Veritone Inc    -2.82  Deteriorating
# 0    ACRS              Aclaris Therapeutics Inc    -2.77  Deteriorating
# 23   RARE         Ultragenyx Pharmaceutical Inc    -2.55  Deteriorating
# 16   KOPN                            Kopin Corp    -2.43  Deteriorating
# 25    SLS        SELLAS Life Sciences Group Inc    -1.86  Deteriorating
# 17   LPTH           Lightpath Technologies, Inc    -0.58  Deteriorating
# 24   SAIL                         Sailpoint Inc    -0.49  Deteriorating
# 5    BULL                           Webull Corp    -0.47  Deteriorating
# 22   PRCH                       Porch Group Inc    -0.44  Deteriorating
# 9    CYTK                      Cytokinetics Inc    -0.16  Deteriorating
# 18   LUNR                Intuitive Machines Inc    -0.07  Deteriorating
# 21   PAYO                   Payoneer Global Inc     0.23  Deteriorating
# 15   INDI               Indie Semiconductor Inc     0.26  Deteriorating
# 6    CNDT                          Conduent Inc     0.28  Deteriorating
# 2     AIV  Apartment Investment & Management Co     0.29  Deteriorating
# 11    EVH                    Evolent Health Inc     0.68  Deteriorating
# 7    CRGY                    Crescent Energy Co     0.71  Deteriorating
# 27   STKL                          Sunopta, Inc     0.90  Deteriorating
# 1    ADPT         Adaptive Biotechnologies Corp     1.03  Deteriorating
# 26   STGW                          Stagwell Inc     1.03  Deteriorating
# 28    TOI                Oncology Institute Inc     1.06  Deteriorating
# 31    VYX                        NCR Voyix Corp     1.11  Deteriorating
# 10    EBS             Emergent Biosolutions Inc     1.14  Deteriorating
# 13   FANG                Diamondback Energy Inc     1.37  Deteriorating
# 30   VRNS                   Varonis Systems Inc     1.55  Deteriorating
# 14    GXO                     GXO Logistics Inc     1.62  Deteriorating
# 20   PACS                        PACS Group Inc     1.63  Deteriorating
# 4    ARDX                           Ardelyx Inc     1.63  Deteriorating
# 19   MTDR                  Matador Resources Co     1.64  Deteriorating
# 8     CWH            Camping World Holdings Inc     1.64  Deteriorating
# 12    EXE                    Expand Energy Corp     1.72  Deteriorating
#
#      Price Recom                  Sector
# 3     1.66   N/A              Healthcare
# 32    8.31   N/A              Healthcare
# 29    5.01   N/A              Technology
# 0     3.14   N/A              Healthcare
# 23   33.50   N/A              Healthcare
# 16    2.40   N/A              Technology
# 25    2.36   N/A              Healthcare
# 17    7.64   N/A              Technology
# 24   21.02   N/A              Technology
# 5     8.57   N/A              Technology
# 22    8.94   N/A              Technology
# 9    62.72   N/A              Healthcare
# 18   14.94   N/A             Industrials
# 21    5.80   N/A              Technology
# 15    3.79   N/A              Technology
# 6     2.06   N/A              Technology
# 2     5.62   N/A             Real Estate
# 11    3.99   N/A              Healthcare
# 7     8.05   N/A                  Energy
# 27    3.71   N/A      Consumer Defensive
# 1    17.00   N/A              Healthcare
# 26    5.18   N/A  Communication Services
# 28    3.50   N/A              Healthcare
# 31   10.37   N/A              Technology
# 10   12.42   N/A              Healthcare
# 13  148.13   N/A                  Energy
# 30   33.42   N/A              Technology
# 14   53.29   N/A             Industrials
# 20   36.39   N/A              Healthcare
# 4     5.68   N/A              Healthcare
# 19   41.11   N/A                  Energy
# 8    10.00   N/A       Consumer Cyclical
# 12  108.74   N/A                  Energy
